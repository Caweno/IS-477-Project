# %%
import pandas as pd

df_pm25 = pd.read_csv("/Users/cawenosu/Downloads/IS 477 Air quality dataset/dailyPM2.5_88101_2024.csv")
# Out:
#                State Name            Parameter Name  Date Local  \
# 0                 Alabama  PM2.5 - Local Conditions  2024-01-02
# 1                 Alabama  PM2.5 - Local Conditions  2024-01-03
# 2                 Alabama  PM2.5 - Local Conditions  2024-01-04
# 3                 Alabama  PM2.5 - Local Conditions  2024-01-05
# 4                 Alabama  PM2.5 - Local Conditions  2024-01-06
# ...                   ...                       ...         ...
# 738473  Country Of Mexico  PM2.5 - Local Conditions  2024-12-27
# 738474  Country Of Mexico  PM2.5 - Local Conditions  2024-12-28
# 738475  Country Of Mexico  PM2.5 - Local Conditions  2024-12-29
# 738476  Country Of Mexico  PM2.5 - Local Conditions  2024-12-30
# 738477  Country Of Mexico  PM2.5 - Local Conditions  2024-12-31
#
#                    Units of Measure  Observation Count  Observation Percent  \
# 0       Micrograms/cubic meter (LC)                 10                 42.0
# ...

# %%
df_co = pd.read_csv('/Users/cawenosu/Downloads/IS 477 Air quality dataset/dailyCO_42101_2024.csv')
df_co
# Out:
#          State Name   Parameter Name  Date Local   Units of Measure  \
# 0           Alabama  Carbon monoxide  2024-01-01  Parts per million
# 1           Alabama  Carbon monoxide  2024-01-02  Parts per million
# 2           Alabama  Carbon monoxide  2024-01-03  Parts per million
# 3           Alabama  Carbon monoxide  2024-01-04  Parts per million
# 4           Alabama  Carbon monoxide  2024-01-05  Parts per million
# ...             ...              ...         ...                ...
# 148817  Puerto Rico  Carbon monoxide  2024-12-27  Parts per million
# 148818  Puerto Rico  Carbon monoxide  2024-12-28  Parts per million
# 148819  Puerto Rico  Carbon monoxide  2024-12-29  Parts per million
# 148820  Puerto Rico  Carbon monoxide  2024-12-30  Parts per million
# 148821  Puerto Rico  Carbon monoxide  2024-12-31  Parts per million
#
#         Observation Count  Observation Percent  Arithmetic Mean
# 0                      24                100.0         0.170833
# ...

# %%
df_no2 = pd.read_csv('/Users/cawenosu/Downloads/IS 477 Air quality dataset/dailyNO2_42602_2024.csv')
df_no2
# Out:
#        State Name          Parameter Name  Date Local   Units of Measure  \
# 0         Alabama  Nitrogen dioxide (NO2)  2024-01-01  Parts per billion
# 1         Alabama  Nitrogen dioxide (NO2)  2024-01-02  Parts per billion
# 2         Alabama  Nitrogen dioxide (NO2)  2024-01-03  Parts per billion
# 3         Alabama  Nitrogen dioxide (NO2)  2024-01-04  Parts per billion
# 4         Alabama  Nitrogen dioxide (NO2)  2024-01-05  Parts per billion
# ...           ...                     ...         ...                ...
# 154716    Wyoming  Nitrogen dioxide (NO2)  2024-12-27  Parts per billion
# 154717    Wyoming  Nitrogen dioxide (NO2)  2024-12-28  Parts per billion
# 154718    Wyoming  Nitrogen dioxide (NO2)  2024-12-29  Parts per billion
# 154719    Wyoming  Nitrogen dioxide (NO2)  2024-12-30  Parts per billion
# 154720    Wyoming  Nitrogen dioxide (NO2)  2024-12-31  Parts per billion
#
#         Observation Count  Observation Percent  Arithmetic Mean
# ...

# %%
df_ozone = pd.read_csv('/Users/cawenosu/Downloads/IS 477 Air quality dataset/dailyOzone_44201_2024.csv')
df_ozone
# Out:
#                State Name Parameter Name  Date Local   Units of Measure  \
# 0                 Alabama          Ozone  2024-02-29  Parts per million
# 1                 Alabama          Ozone  2024-03-01  Parts per million
# 2                 Alabama          Ozone  2024-03-02  Parts per million
# 3                 Alabama          Ozone  2024-03-03  Parts per million
# 4                 Alabama          Ozone  2024-03-04  Parts per million
# ...                   ...            ...         ...                ...
# 387029  Country Of Mexico          Ozone  2024-12-27  Parts per million
# 387030  Country Of Mexico          Ozone  2024-12-28  Parts per million
# 387031  Country Of Mexico          Ozone  2024-12-29  Parts per million
# 387032  Country Of Mexico          Ozone  2024-12-30  Parts per million
# 387033  Country Of Mexico          Ozone  2024-12-31  Parts per million
#
#         Observation Count  Observation Percent  Arithmetic Mean
# ...

# %%
df_so2 = pd.read_csv('/Users/cawenosu/Downloads/IS 477 Air quality dataset/dailySO2_42401_2024.csv')
df_so2
# Out:
#          State Name  Parameter Name  Date Local   Units of Measure  \
# 0           Alabama  Sulfur dioxide  2024-01-01  Parts per billion
# 1           Alabama  Sulfur dioxide  2024-01-02  Parts per billion
# 2           Alabama  Sulfur dioxide  2024-01-03  Parts per billion
# 3           Alabama  Sulfur dioxide  2024-01-04  Parts per billion
# 4           Alabama  Sulfur dioxide  2024-01-05  Parts per billion
# ...             ...             ...         ...                ...
# 268197  Puerto Rico  Sulfur dioxide  2024-10-25  Parts per billion
# 268198  Puerto Rico  Sulfur dioxide  2024-10-26  Parts per billion
# 268199  Puerto Rico  Sulfur dioxide  2024-10-27  Parts per billion
# 268200  Puerto Rico  Sulfur dioxide  2024-10-28  Parts per billion
# 268201  Puerto Rico  Sulfur dioxide  2024-10-29  Parts per billion
#
#         Observation Count  Observation Percent  Arithmetic Mean
# 0                      24                100.0         1.041667
# ...

# %%
df_all = pd.concat([df_pm25, df_co, df_no2,df_ozone,df_so2], ignore_index=True)

# %%
df_all
# Out:
#           State Name            Parameter Name  Date Local  \
# 0            Alabama  PM2.5 - Local Conditions  2024-01-02
# 1            Alabama  PM2.5 - Local Conditions  2024-01-03
# 2            Alabama  PM2.5 - Local Conditions  2024-01-04
# 3            Alabama  PM2.5 - Local Conditions  2024-01-05
# 4            Alabama  PM2.5 - Local Conditions  2024-01-06
# ...              ...                       ...         ...
# 1697252  Puerto Rico            Sulfur dioxide  2024-10-25
# 1697253  Puerto Rico            Sulfur dioxide  2024-10-26
# 1697254  Puerto Rico            Sulfur dioxide  2024-10-27
# 1697255  Puerto Rico            Sulfur dioxide  2024-10-28
# 1697256  Puerto Rico            Sulfur dioxide  2024-10-29
#
#                     Units of Measure  Observation Count  Observation Percent  \
# 0        Micrograms/cubic meter (LC)                 10                 42.0
# 1        Micrograms/cubic meter (LC)                 24                100.0
# ...
